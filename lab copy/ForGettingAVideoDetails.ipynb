# %%
import requests
from dotenv import load_dotenv
from urllib.parse import urlparse
from urllib.parse import parse_qs
from os import getenv
from requests.models import PreparedRequest
from requests import get

load_dotenv()
# Out:
# False

# %%
u = 'https://www.youtube.com/watch?v=9yDDnurRmIY'


def get_video_key(p_url):
    parsed_url = urlparse(p_url)
    captured_value = parse_qs(parsed_url.query)['v'][0]
    return captured_value

get_video_key(u)
# Out:
# '9yDDnurRmIY'

# %% [markdown]
# # Understanding the Results of the Video
#
# we call the [GetVideos](https://developers.google.com/youtube/v3/docs/videos/list?apix_params=%7B%22part%22%3A%5B%22snippet%2CcontentDetails%2Cstatistics%22%5D%2C%22id%22%3A%5B%229yDDnurRmIY%22%5D%7D#usage) API which can give the information for single or multiple videos, here we are focusing on the single video.
#
# | Part                        | What is it for                             |
# |-----------------------------|--------------------------------------------|
# | contentDetails              | Has the Duration of the Video              |
# | localizations               | Has the Title and Description of the Video |
# | paidProductPlacementDetails | if the Video has any Product ADs related   |
# | player                      | URL for embedding the video (IFRAME URL)   |
# | snippet                     | has tags and more info. on the Video       |
# | statistics                  | views, likes, ... (stats on the video)     |
# | topicDetails                | Topic Classification Ig                    |

# %%
def add_key(params):
    return {"key": getenv('API_KEY'), **params}

    
def get_video_details(p_url):
    video_key = get_video_key(p_url)
    url = 'https://www.googleapis.com/youtube/v3/videos'
    params = add_key({
      'id': video_key,
      'part': 'contentDetails,localizations,paidProductPlacementDetails,player,snippet,statistics,topicDetails'
    })
    req = PreparedRequest()
    req.prepare_url(url, params)
    return get(req.url)

# %%
def search_results(q):
    url = 'https://www.googleapis.com/youtube/v3/search'
    params = add_key({
      'q': q,
      'part': 'snippet',
        'maxResults': 5
    })
    req = PreparedRequest()
    req.prepare_url(url, params)
    return get(req.url)

search_results("how to make a chocolate cake, can you help with me it").json()
# Out:
# {'error': {'code': 403,
#   'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.",
#   'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.",
#     'domain': 'global',
#     'reason': 'forbidden'}],
#   'status': 'PERMISSION_DENIED'}}

# %%
search_results("how to make a chocolate cake ?").json()
# Out:
# {'error': {'code': 403,
#   'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.",
#   'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.",
#     'domain': 'global',
#     'reason': 'forbidden'}],
#   'status': 'PERMISSION_DENIED'}}

# %%
resp = get_video_details('https://www.youtube.com/watch?v=9yDDnurRmIY')
resp.json()
# Out:
# {'error': {'code': 403,
#   'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.",
#   'errors': [{'message': "Method doesn't allow unregistered callers (callers without established identity). Please use API Key or other form of API consumer identity to call this API.",
#     'domain': 'global',
#     'reason': 'forbidden'}],
#   'status': 'PERMISSION_DENIED'}}

# %% [markdown]
# # Getting the Transcripts
#
# First we can use the [Captions](https://www.googleapis.com/youtube/v3/captions) API in order to fetch the caption id, there can be multiple transcripts or captions for a video so

# %%
def get_caption_items(u):
    c_url = 'https://www.googleapis.com/youtube/v3/captions'
    video_key = get_video_key(u)
    params = add_key({
      'videoId': video_key,
      'part': 'snippet'
    })
    req = PreparedRequest()
    req.prepare_url(c_url, params)
    return get(req.url)

# %%
resp = get_caption_items('https://www.youtube.com/watch?v=9yDDnurRmIY')
m = resp.json()
m, m["items"][0]["id"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 3
#       1 resp = get_caption_items('https://www.youtube.com/watch?v=9yDDnurRmIY')
#       2 m = resp.json()
# ----> 3 m, m["items"][0]["id"]
#
# KeyError: 'items'

# %%
def get_captions(track_id):
    c_url = 'https://www.googleapis.com/youtube/v3/captions/id'
    video_key = get_video_key(u)
    params = add_key({
      'id': track_id,
    })
    req = PreparedRequest()
    req.prepare_url(c_url, params)
    return get(req.url)

# %%
resp = get_captions(m["items"][0]["id"])
resp
# Out:
# <Response [401]>

# %% [markdown]
# # Another Approach
#
# Since the Official Youtube data API does not allow the users who do not own the video to download the captions, but its from Unofficial service.
#
# [youtube-transcript-api](https://github.com/jdepoix/youtube-transcript-api)
#
# `uv add youtube-transcript-api`

# %%
from youtube_transcript_api import YouTubeTranscriptApi

ytt_api = YouTubeTranscriptApi()

fetch = ytt_api.fetch(get_video_key('https://www.youtube.com/watch?v=9yDDnurRmIY'))
fetch2 = ytt_api.fetch(get_video_key('https://www.youtube.com/watch?v=y_q741QO_m0'))
fetches = [fetch.to_raw_data(), fetch2.to_raw_data()]
print(fetch)
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='oh you got to be kidding me zero Ubers', start=0.96, duration=5.52), FetchedTranscriptSnippet(text="we're in the middle of downtown", start=3.659, duration=5.341), FetchedTranscriptSnippet(text='hey get in who the hell are you a really', start=6.48, duration=4.079), FetchedTranscriptSnippet(text="bad start to your day that's who were", start=9.0, duration=3.059), FetchedTranscriptSnippet(text='you just waiting for me out here all day', start=10.559, duration=3.54), FetchedTranscriptSnippet(text='yes sir well do you have like an app to', start=12.059, duration=3.301), FetchedTranscriptSnippet(text="make sure it's safe yeah it's called", start=14.099, duration=3.241), FetchedTranscriptSnippet(text='take my word for it and get the hell in', start=15.36, duration=4.86), FetchedTranscriptSnippet(text='ah you can help me with my bags no we', start=17.34, duration=4.199), FetchedTranscriptSnippet(text="don't work for five star ratings get", start=20.22, duration=4.16), FetchedTranscriptSnippet(text='yourself dirtbag', start=21.539, duration=2.841), FetchedTranscriptSnippet(text="what does it feel like I'm in the back", start=25.56, duration=2.4), FetchedTranscriptSnippet(text="of a police car oh that's just because", start=26.699, duration=3.061), FetchedTranscriptSnippet(text='all taxis are retired police cars you', start=27.96, duration=3.3), FetchedTranscriptSnippet(text='got your seatbelt on no not yet just', start=29.76, duration=3.72), FetchedTranscriptSnippet(text='give me a sec and here we go', start=31.26, duration=4.139), FetchedTranscriptSnippet(text='so where are we going today uh just take', start=33.48, duration=3.419), FetchedTranscriptSnippet(text='me to the airport please yep not a', start=35.399, duration=2.461), FetchedTranscriptSnippet(text='problem', start=36.899, duration=2.521), FetchedTranscriptSnippet(text='hey you mind putting that cigarette out', start=37.86, duration=3.3), FetchedTranscriptSnippet(text="oh that's not me that's just all taxi", start=39.42, duration=3.78), FetchedTranscriptSnippet(text='sir do you have any air fresheners yeah', start=41.16, duration=4.2), FetchedTranscriptSnippet(text='but they also smell like cigarettes do', start=43.2, duration=3.0), FetchedTranscriptSnippet(text="you have anything that doesn't smell", start=45.36, duration=3.359), FetchedTranscriptSnippet(text='like cigarettes no', start=46.2, duration=3.78), FetchedTranscriptSnippet(text="hey what's that machine with all the", start=48.719, duration=2.52), FetchedTranscriptSnippet(text="numbers oh that's just how much money", start=49.98, duration=2.88), FetchedTranscriptSnippet(text="you're gonna give me why is it already", start=51.239, duration=3.061), FetchedTranscriptSnippet(text="at 20 bucks oh I wouldn't worry about", start=52.86, duration=3.48), FetchedTranscriptSnippet(text="that and why is it going up so fast it's", start=54.3, duration=3.12), FetchedTranscriptSnippet(text='about to get a lot higher so how about', start=56.34, duration=3.899), FetchedTranscriptSnippet(text='you chill out and get that wallet ready', start=57.42, duration=4.5), FetchedTranscriptSnippet(text='so are you intentionally driving like', start=60.239, duration=3.66), FetchedTranscriptSnippet(text=" or oh that's just part of the taxi", start=61.92, duration=3.48), FetchedTranscriptSnippet(text='experience sir do you even have a', start=63.899, duration=3.9), FetchedTranscriptSnippet(text="driver's license", start=65.4, duration=4.5), FetchedTranscriptSnippet(text='what for', start=67.799, duration=3.661), FetchedTranscriptSnippet(text='please look at the road how about we get', start=69.9, duration=3.12), FetchedTranscriptSnippet(text='some music going shall we', start=71.46, duration=3.06), FetchedTranscriptSnippet(text='are we listening to the radio right now', start=73.02, duration=3.599), FetchedTranscriptSnippet(text='uh yeah what else will we listen to okay', start=74.52, d ...

# %%
print(
    fetch.video_id,
    fetch.language,
    fetch.language_code,
    # whether it has been manually created or generated by YouTube
    fetch.is_generated, sep="\n"
)
# Out:
# 9yDDnurRmIY
# English (auto-generated)
# en
# True

# %%
fetch2.to_raw_data()[:5]
# Out:
# [{'text': "In September 2025, Trump hosted a dinner\nfor Big Tech's top CEOs.",
#   'start': 0.0,
#   'duration': 4.629},
#  {'text': 'The most brilliant people\nare gathered around this table.',
#   'start': 4.629,
#   'duration': 2.711},
#  {'text': '[Trevor]\nMeta, Google, Microsoft, OpenAI.',
#   'start': 7.34,
#   'duration': 3.462},
#  {'text': 'Everyone was there.', 'start': 10.802, 'duration': 1.084},
#  {'text': '[Trump]\nThis is definitely a high IQ group.',
#   'start': 12.303,
#   'duration': 2.044}]

# %%
def raw_data_to_single_text(raw_data):
    texts = "".join(f"{i['text'].replace("\n", " ")} \n" for i in raw_data)
    return "POST: " + texts


# raw = fetch.to_raw_data()
# text = raw_data_to_single_text(raw)
# print(text)

# %%
def create_list_from_fetches(fetches_list: list):
    return list(map(raw_data_to_single_text, fetches_list))

def format_df(df):
    df["text"] = create_list_from_fetches(df["text"])
    df["text"] = "TITLE: " + df["title"] + "\n\n" + df["text"]
    return df

df = pd.DataFrame({"text":  fetches, "title": ["Uber", "Politics"]})
df = format_df(df)
print(df["text"])
print("\n" + df["text"][1])
# Out:
# 0    TITLE: Uber\n\nPOST: oh you got to be kidding ...
# 1    TITLE: Politics\n\nPOST: In September 2025, Tr...
# Name: text, dtype: object
#
# TITLE: Politics
#
# POST: In September 2025, Trump hosted a dinner for Big Tech's top CEOs.
# The most brilliant people are gathered around this table.
# [Trevor] Meta, Google, Microsoft, OpenAI.
# Everyone was there.
# [Trump] This is definitely a high IQ group.
# [Trevor] It was the usual scene: a bunch of people
# around a table praising Trump, thanking him for everything that he's doing.
# [Mark Zuckerberg] Well, thanks for hosting us.
# [Jared Isaacman] Thank you so much.
# [Bill Gates] Thank you.
# [Tim Cook] Thank you for including me.
# [Sam Altman] Thank you for being such a pro-business,
# pro-innovation president.
# [Greg Brockman] Thank you for that.
# [Safra Catz] Thank you.
# But I've got to admit, this dinner in particular, it had me scratching my head.
# It was weird.
# And not just because Zuckerberg got caught on a hot mic trying to be the teacher's pet.
# [Zuckerberg] All of the companies here
# are making huge investments in the country.
# [Trump] How much are you spending,
# would you say, over the next few years?
# [Zuckerberg] Oh, gosh.
# I don't know, at least $600 billion.
# Sorry, I wasn’t ready to do our...
# I wasn’t sure what number you wanted to go with.
# Trump and Trump allies  have historically been anti-tech.
# There's no question that what
# the big tech companies are doing is very bad.
# I think Big Tech has made a terrible mistake and very, very bad for our country.
# The presidency that started the antitrust lawsuit
#  against Google was Donald J. Trump’s presidency.
# You've got to take on those monopolies. President Trump already did it,
# and I think he'll do it again  if we give him another chance.
# [Trevor] In fact, Trump's first administration sued Google
# and Meta, and they tried to ban TikTok.
# So when I saw this dinner,
# and when I saw this scene at his inauguration,
# I was more than a little surprised.
# What changed?
# How did we go from this...
# [Trump] I’m filing a major class action lawsuit
# against the big tech giants, including Facebook, Google and Twitter.
# ...to this?
# [Trump] This is definitely a high IQ group.
# They're leading a revolution  in business and in genius.
# Well, we can't say for sure,
# but I'm guessing all these donations didn't hurt.
# And the switch up on Big Tech, it's just scratching the surface.
# Are we supposed to pretend that multibillion dollar corporations
# make multimillion dollar payments and do not expect anything in exchange for those things?
# [Trevor] You’re looking at all of Big Tech's donations
# to the second inauguration of Donald Trump.
# Each company gave about $1 million to the new president
# to throw a massive inauguration party, which many of their CEOs attended.
# How did they get away with giving the president $1 million each?
# Because there are almost no rules regulating inauguration funds,
# no laws saying what the funds have to be spent on,
#  no limits on how much can be donated or who can even donate.
# And as a result, inauguration funds
# have become a major tool for corporate interests to buy influence in our government.
# Another way to flatter and buy out Donald Trump.
# And the strategy is working.
# Before the inauguration, Meta was not in good standing with the government or with Donald Trump.
# [Trump] I consider Facebook to be an enemy of the people,
# along with a lot of the media.
# [Trevor] Under Biden, the Consumer Financial Protection Bureau
# was investigating Meta for illegally harvesting users’ financial data
# to sell more ads on their platform.
# Then Trump takes office, Meta donates $1 million, and the investigation vanishes.
# In fact, the Trump administration has basically shut down
# the Consumer Financial Protection Bureau entirely,
# which is great for Mark Zuckerberg, but not so much for the entire idea of protecting consumers.
# Google is playing the same game as Meta.
# In 2020, the previous Trump administration opened an antitrust case against Google.
# They said that Google had created an unfair monopoly, something about running the single biggest
# search engine and the single biggest web browser at the same time
#  seemed a little unfair, I guess.
# Google actually lost that case technically,
# but the judge ruled that Google wouldn't have to change its business in any major way.
# They could keep the Chrome web browser as long as they paid a measly fine
# that they could basically dig out of their couch cushions.
# A lot of people saw it as a major blow to antitrust efforts.
# And yet, five years after he opened the lawsuit, Trump changed course
# and congratulated the CEO of Google on this favorable ruling.
# [Trump] Do you want to talk about that big day you had yesterday?
# [Sundar Pichai] I'm glad it's over and uh–
# [Trump] Don’t forget,
# Biden was the one that prosecuted that lawsuit.
# You know that, right?
# [Trevor] Google’s stock price, of course,
#  skyrocketed after the ruling.
# Then there's Apple.
# Tim Cook personally donated $1 million to the inauguration,
# and for his donation, Apple has been given a lot of preferential treatment.
# Just this past April, Apple was in a tough spot.
# Trump had just announced huge tariffs on all kinds of goods coming from
# foreign countries, tariffs that would raise Apple's cost of doing business by billions.
# Weeks later, after Tim Cook met with Trump, the White House
# announced tariff exemptions for smartphones, computers and chips.
# You know, the things that Apple makes.
# So a $1 million donation for Apple and billions in savings.
# I guess that's what economists would call a return on investment.
# To me it just looks like a bribe with extra steps.
# Microsoft, you guessed it, also got in on the action
# with a $750,000 donation.
# And like Google, they got the FTC off their back–
# a major antitrust case against them dropped for a huge merger they did in 2023 with Activision.
# Amazon reached a big settlement with the FTC for essentially tricking consumers
# into signing up for Amazon Prime,
# a case the FTC could easily have won.
# So why would they suddenly settle?
# Are you starting to see a pattern yet?
# Well, just wait, it's about to get worse.
# According to research done by Public Citizen, 1 in 3 lawsuits
# brought against Big Tech by the government have now been dropped by the Trump administration.
# So if these donations are all paying off for Big Tech,
# you really have to wonder,
# what else is being bought by all these donations?
# What you're looking at now is
# the biggest inaugural fund in the history of the United States.
# You might be wondering, why are we talking about the inauguration now, months later?
# Well, first, information about donors take months
# to be reported to the public, and some donors try to hide their donations.
# Second, inaugural funds have become a major tool
# for corporate interests to buy influence in our government.
# We have all this data because OpenSecrets combed through the Federal Election
# Commission filings to find out who donated.
# Over $240 million, nearly 800 donors,
# and like I said before, no rules about how that money
# has to be spent, managed, or where it can come from.
# Even the Trump team can't find a way to spend $240 million on a party.
# So what's happening with all that leftover money and who's managing it?
# There is an opportunity here for unprecedented
# levels of corruption, unlimited corporate money flowing into the coffers
# of the Trump inaugural fund, buying access without any oversight.
# So, of course,
# Big Tech companies weren't the only ones throwing their hats in the ring.
# Up first, the top donor:
# A company called Pilgrim's Pride contributed $5 million.
# They're one of the top chicken producers in the United States
# and this was their biggest political donation ever.
# And you know what?
# It looks like they're getting good value for their money,
# because in March of this year, just a few months after the inauguration,
# the USDA started changing the rules around poultry production.
# The USDA decided to let poultry giants speed up
# production despite serious safety concerns.
# Unions pointed out that increased speeds will mean more injured workers in an industry
# where over 80% of workers are already at risk for repetitive-use injuries.
# And yeah, that makes sense,
# but I guess the unions didn't have $5 million to give to the Trump administration.
# Next up, Big Oil: ConocoPhillips and Chevron.
# On the first day of the new administration,
# Trump signed an order to expand drilling on federal land in Alaska.
# Then they passed the One Big Beautiful Bill, which had
# $18 billion in tax breaks and incentives for Big Oil.
# Then in July, they reversed their own ban
# and decided that Chevron should definitely be allowed to operate in Venezuela.
# And I'm sure the $2 million donation had nothing to do with it.
# NVIDIA got in on the action with a million dollar donation.
# And what did they get?
# Permission.
# The government had previously banned NVIDIA from selling their most advanced AI chips to China
# on the grounds that China would be using them for the military.
# Not the case anymore.
# AI chips can be sold to China again, although NVIDIA does
# have to share 15% of the revenue with the U.S. government.
# Just like with Apple, tariffs seem to only apply to
# people who lack direct access to the president.
# Boeing made a contribution after having a very bad couple of years.
# You might remember a few years ago their planes were literally falling out of the sky.
# Hundreds of people died.
# It seems like the kind of thing that there might a trial over.
# But in May, the Department of Justice made a deal
# with Boeing to not prosecute them for crimes over the 737 crashes,
# as long as Boeing paid about $1.1 billion in fines.
# Sounds like a lot of money until you learn that Boeing had just won a contract
# for $50 billion with the Department of Defense
# to build new F-47 fighter jets.
# Looks a lot like a preferential slap on the wrist to me.
# If you hate the current state of air travel, then you'll be interested
# to hear that Delta and United both made major donations.
# Then the Trump administration turned around and killed new rules
# that would force airlines to compensate passengers for excessive delays.
# In response to this move, and the rollback of other rules
# about hidden fees and flight cancellations, the airline said,
# “We look forward to working with the Department of Transportation on
# implementing President Trump's deregulatory agenda.”
# Yeah, I bet they do.
# The crypto industry also came in with some of the biggest donations for President Trump.
# Crypto companies and schemes rocketed to the center of the Trump world
# at the start of this year when Trump passed the Genius Act, the first major piece of legislation
# that brings cryptocurrencies into the formal economy,
# started dropping major investigations into crypto
# companies, created a strategic cryptocurrency reserve for the government,
# and launched his own meme coin on the Solana blockchain,
# another major donor.
# Which is a long-winded sentence
# that I can't believe I just had to say.
# And maybe the worst part of all of these donors
# are the ones that we don't know anything about:
# the shell companies, political action committees,
# and the fake non-profits that were made to hide who the real donors are.
# Americans for Pharma Reform, Election Freedom, Inc.,
# Axe Capital, all untraceable dark money.
# We'll probably never know who they were or what influence they bought.
# So, yes, technically, no one has broken the law here,
# but shouldn't we care when massive corporations buy influence at the cost of the public?
# $1 million to spare?
# You can have dinner with the president, and he might even listen to your concerns.
# $5 million to spare?
# You can probably buy a whole policy.
# To me, this looks a lot like a system of patronage–
# a government that operates on fealty, bribes, personal favors, and insider access.
# It's not just the inauguration and all this money.
# It's how the Trump administration has attacked big law firms to get them to offer free work.
# It's how they sued media companies to get them to take people off
# the air that don't give Trump favorable coverage.
# It's how they force private companies to bend the knee to comply with Trump's preferences.
# It's how they threaten to withhold funding from states with governors
# that Trump doesn't like.
#  The inaugural fund was just one move
# in the playbook, a move that re-centers corporate power at your expense.

# %%
# Out:
# /Users/thorkildkappel/Desktop/7. sem/NLP /project/NLP_project_group6/lab copy

# %%
f = open('../data/queries.txt', 'r')
content = f.read()

print(len(content.split(",")))
# Out:
# 1127
