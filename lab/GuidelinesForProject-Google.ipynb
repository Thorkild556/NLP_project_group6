# %% [markdown]
# # Create Project
#
# ![image.png](attachment:9d8b4543-6502-4f68-a694-b356b8bf8335.png)

# %% [markdown]
# # Under Enable API Services
#
# ![image.png](attachment:173c50b7-4313-41db-bbd2-d4e472c52d23.png)

# %% [markdown]
# # Select Youtube Data API
# And then enable it
#
# ![image.png](attachment:1e444517-54d8-4a1d-8f06-9d9d016050e6.png)

# %% [markdown]
# # Create Creds
#
# ![image.png](attachment:556601c6-325a-44c7-910c-ed5a8ee612d8.png)

# %% [markdown]
# # Create API Key
#
#
# ![image.png](attachment:3a05442f-b110-452a-bc8f-599941e2256a.png)

# %% [markdown]
# Once you create it you will get your API_KEY copy it and save it in .env file as API_KEY={}
